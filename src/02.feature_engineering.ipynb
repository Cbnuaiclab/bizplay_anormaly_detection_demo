# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from datetime import time

# %%
df = pd.read_excel('../dataset/BizPlay-2025_JAN.xlsx', sheet_name='2025년1월 거래데이터')
df

# %%
df.isnull().sum()
# Out:
# Transaction Date                             0
# Transaction Time                             0
# Transaction Amount                           0
# Customer Date of Birth                       0
# Customer Gender                              0
# Customer Age                                 0
# Customer Region (City/County/District)       0
# Merchant Region (City/County/District)       0
# Merchant ID                                  0
# Sub-Merchant ID                           9622
# Transaction Processing Agency (VAN)          0
# Distance                                     0
# dtype: int64

# %%
df['Sub-Merchant ID'] = df['Sub-Merchant ID'].fillna(0)
df
# Out:
#         Transaction Date  Transaction Time  Transaction Amount  \
# 0               20250101            225951               30500
# 1               20250101            225950               15500
# 2               20250101            225936               10500
# 3               20250101            225917                5800
# 4               20250101            225904                5000
# ...                  ...               ...                 ...
# 323456          20250131             61432               15580
# 323457          20250131             60746                6050
# 323458          20250131             60728               31900
# 323459          20250131             60711               10300
# 323460          20250131             60444                3100
#
#         Customer Date of Birth  Customer Gender  Customer Age  \
# 0                       140929                4            10
# 1                        90921                4            15
# 2                        80912                3            16
# 3                        91111                3            15
# 4                       110224                3            14
# ...                        ...              ...           ...
# 323456                  151031                4             9
# 323457                   71023                3            17
# 323458                   70504                3            17
# 323459                  110420                3            14
# 323460                  100912                3            14
#
#         Customer Region (City/County/District)  \
# 0                                        41133
# 1                                        41220
# 2                                        41150
# 3                                        41430
# 4                                        41360
# ...                                        ...
# 323456                                   41670
# 323457                                   41273
# 323458                                   41173
# 323459                                   41173
# 323460                                   41287
#
#        Merchant Region (City/County/District) Merchant ID Sub-Merchant ID  \
# 0                                      ONLINE  F000000001      S220106718
# 1                                       41220  F000000018     00917255276
# 2                                       41150  F000000018     00913070265
# 3                                       41430  F000000018     00912455517
# 4                                       41360  F000000018     00919265356
# ...                                       ...         ...             ...
# 323456                                  41670  F000000018     00922577359
# 323457                                  41273  F000000018     00921032828
# 323458                                 ONLINE  F000000001      S230127579
# 323459                                  41173  F000000018     00979351269
# 323460                                  41287  F000000018     00921292778
#
#         Transaction Processing Agency (VAN)  Distance
# 0                                        52         0
# 1                                        55         0
# 2                                        55         0
# 3                                        55         0
# 4                                        55         0
# ...                                     ...       ...
# 323456                                   55         0
# 323457                                   55         0
# 323458                                   52         0
# 323459                                   55         0
# 323460                                   55         0
#
# [323461 rows x 12 columns]

# %%
df.isnull().sum()
# Out:
# Transaction Date                          0
# Transaction Time                          0
# Transaction Amount                        0
# Customer Date of Birth                    0
# Customer Gender                           0
# Customer Age                              0
# Customer Region (City/County/District)    0
# Merchant Region (City/County/District)    0
# Merchant ID                               0
# Sub-Merchant ID                           0
# Transaction Processing Agency (VAN)       0
# Distance                                  0
# dtype: int64

# %% [markdown]
# ### Use Your Rules to Label Pseudo-Anomalies

# %%
outside_district = (
        (df['Customer Region (City/County/District)'].astype(str).str.strip() != df['Merchant Region (City/County/District)'].astype(str).str.strip()) &
        (df['Merchant Region (City/County/District)'] != 'ONLINE')
)
outside_district.sum()  # This tells you how many True rows
# Out:
# 26203

# %%
df['anomaly'] = 0
df.loc[outside_district, 'anomaly'] = 1

df['anomaly'].value_counts()
# Out:
# anomaly
# 0    297258
# 1     26203
# Name: count, dtype: int64

# %%
parsed_time = pd.to_datetime(df['Transaction Time'], format='%H%M%S').dt.time
rule_kids_after_10pm = (df['Customer Age'] < 8) & (parsed_time >= time(22, 0))
df.loc[rule_kids_after_10pm, 'anomaly'] = 1

df['anomaly'].value_counts()
# Out:
# anomaly
# 0    296975
# 1     26486
# Name: count, dtype: int64

# %%
late_night_mask = (parsed_time >= time(23, 0)) | (parsed_time < time(6, 0))
df.loc[late_night_mask, 'anomaly'] = 1

df['anomaly'].value_counts()
# Out:
# anomaly
# 0    296963
# 1     26498
# Name: count, dtype: int64

# %%
financial_aid_recipients_during_school_term = (parsed_time >= time(11, 0)) & (parsed_time < time(13, 0))
df.loc[financial_aid_recipients_during_school_term, 'anomaly'] = 1

df['anomaly'].value_counts()
# Out:
# anomaly
# 0    258725
# 1     64736
# Name: count, dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder

for col in ['Customer Gender', 'Merchant ID', 'Sub-Merchant ID',
            'Transaction Processing Agency (VAN)']:
    df[col] = LabelEncoder().fit_transform(df[col].astype(str))

# %%
region_cols = ['Customer Region (City/County/District)', 'Merchant Region (City/County/District)']
region_df = df[region_cols].copy()

# Apply shared LabelEncoder
combined_region = pd.concat([
    region_df['Customer Region (City/County/District)'],
    region_df['Merchant Region (City/County/District)']
])

encoder = LabelEncoder()
encoder.fit(combined_region.astype(str))

df['Customer_Encoded'] = encoder.transform(region_df['Customer Region (City/County/District)'].astype(str))
df['Merchant_Encoded'] = encoder.transform(region_df['Merchant Region (City/County/District)'].astype(str))
df
# Out:
#         Transaction Date  Transaction Time  Transaction Amount  \
# 0               20250101            225951               30500
# 1               20250101            225950               15500
# 2               20250101            225936               10500
# 3               20250101            225917                5800
# 4               20250101            225904                5000
# ...                  ...               ...                 ...
# 323456          20250131             61432               15580
# 323457          20250131             60746                6050
# 323458          20250131             60728               31900
# 323459          20250131             60711               10300
# 323460          20250131             60444                3100
#
#         Customer Date of Birth  Customer Gender  Customer Age  \
# 0                       140929                1            10
# 1                        90921                1            15
# 2                        80912                0            16
# 3                        91111                0            15
# 4                       110224                0            14
# ...                        ...              ...           ...
# 323456                  151031                1             9
# 323457                   71023                0            17
# 323458                   70504                0            17
# 323459                  110420                0            14
# 323460                  100912                0            14
#
#         Customer Region (City/County/District)  \
# 0                                        41133
# 1                                        41220
# 2                                        41150
# 3                                        41430
# 4                                        41360
# ...                                        ...
# 323456                                   41670
# 323457                                   41273
# 323458                                   41173
# 323459                                   41173
# 323460                                   41287
#
#        Merchant Region (City/County/District)  Merchant ID  Sub-Merchant ID  \
# 0                                      ONLINE            0            51565
# 1                                       41220            1            18979
# 2                                       41150            1            12525
# 3                                       41430            1            11742
# 4                                       41360            1            22529
# ...                                       ...          ...              ...
# 323456                                  41670            1            28837
# 323457                                  41273            1            25911
# 323458                                 ONLINE            0            53116
# 323459                                  41173            1            36344
# 323460                                  41287            1            26395
#
#         Transaction Processing Agency (VAN)  Distance  anomaly  \
# 0                                         2         0        0
# 1                                         3         0        0
# 2                                         3         0        0
# 3                                         3         0        0
# 4                                         3         0        0
# ...                                     ...       ...      ...
# 323456                                    3         0        0
# 323457                                    3         0        0
# 323458                                    2         0        0
# 323459                                    3         0        0
# 323460                                    3         0        0
#
#         Customer_Encoded  Merchant_Encoded
# 0                     13                56
# 1                     22                22
# 2                     15                15
# 3                     36                36
# 4                     32                32
# ...                  ...               ...
# 323456                50                50
# 323457                25                25
# 323458                17                56
# 323459                17                17
# 323460                29                29
#
# [323461 rows x 15 columns]

# %%
df.to_csv("../dataset/cleaned_BizPlay_2025_JAN.csv", index=False)

# %%
df['anomaly'].value_counts()
# Out:
# anomaly
# 0    258725
# 1     64736
# Name: count, dtype: int64
